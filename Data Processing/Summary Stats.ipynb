# %%
from pathlib import Path
import os
import pandas as pd

# %%
src_path = Path("/home/dmacs/Documents/Final Dissertation/Data/Prices/Individual Collated/Excel/")
resultsPath = Path("/home/dmacs/Documents/Pranav_Phanindra/Time Series Implementations/Results/12_Mustard")
#Directory containing all the files
DataFiles = os.listdir(src_path)
DataFiles
# Out:
# ['13_Soyabean.xlsx',
#  '12_Mustard.xlsx',
#  '1_Wheat.xlsx',
#  '4_Maize.xlsx',
#  '6_Bengal+Gram(Gram)(Whole).xlsx',
#  '29_Barley_(Jau).xlsx',
#  '263_Bengal_Gram_Dal_(Chana_Dal).xlsx']

# %%
filename = DataFiles[6]

CropData = pd.read_excel(src_path / filename)

CropData
# Out:
#         District Name             Market Name                     Commodity  \
# 0         Hazaribagh              Hazaribagh   Bengal Gram Dal (Chana Dal)
# 1         Hazaribagh              Hazaribagh   Bengal Gram Dal (Chana Dal)
# 2         Hazaribagh              Hazaribagh   Bengal Gram Dal (Chana Dal)
# 3            Koderma                 Koderma   Bengal Gram Dal (Chana Dal)
# 4            Koderma                 Koderma   Bengal Gram Dal (Chana Dal)
# ...               ...                     ...                           ...
# 58382         Kanpur                    Rura   Bengal Gram Dal (Chana Dal)
# 58383     Saharanpur              Saharanpur   Bengal Gram Dal (Chana Dal)
# 58384  Muzaffarnagar                  Shamli   Bengal Gram Dal (Chana Dal)
# 58385          Unnao                   Unnao   Bengal Gram Dal (Chana Dal)
# 58386         Howrah   Ramkrishanpur(Howrah)   Bengal Gram Dal (Chana Dal)
#
#                     Variety Grade  Min Price (Rs./Quintal)  \
# ...

# %%
CropData['Price Date'] =  pd.to_datetime(CropData['Price Date'])

CropData['Yr-mon'] = CropData['Price Date'].dt.strftime('%Y%m')
CropData['Yr-mon'] = pd.to_datetime(CropData['Yr-mon'], format = '%Y%m')

CropData['Year'] = CropData.set_index('Yr-mon').index.year
CropData['Month'] = CropData.set_index('Yr-mon').index.month

CropData.set_index('Price Date')
# Out:
#              District Name             Market Name  \
# Price Date
# 2012-05-22     Hazaribagh              Hazaribagh
# 2012-05-24     Hazaribagh              Hazaribagh
# 2012-05-29     Hazaribagh              Hazaribagh
# 2012-07-25        Koderma                 Koderma
# 2012-07-28        Koderma                 Koderma
# ...                    ...                     ...
# 2022-03-31         Kanpur                    Rura
# 2022-03-31     Saharanpur              Saharanpur
# 2022-03-31  Muzaffarnagar                  Shamli
# 2022-03-31          Unnao                   Unnao
# 2022-03-31         Howrah   Ramkrishanpur(Howrah)
#
#                                Commodity               Variety Grade  \
# Price Date
# 2012-05-22  Bengal Gram Dal (Chana Dal)                 Other   FAQ
# 2012-05-24  Bengal Gram Dal (Chana Dal)                 Other   FAQ
# 2012-05-29  Bengal Gram Dal (Chana Dal)                 Other   FAQ
# ...

# %%
CropData.describe()
# Out:
#        Min Price (Rs./Quintal)  Max Price (Rs./Quintal)  \
# count             58387.000000             58387.000000
# mean               5575.040077              6043.746707
# std                1699.469784              1672.047275
# min                   0.000000                 0.000000
# 25%                5100.000000              5400.000000
# 50%                5700.000000              5970.000000
# 75%                6300.000000              6530.000000
# max               16500.000000             18000.000000
#
#        Modal Price (Rs./Quintal)          Year         Month
# count               58387.000000  58387.000000  58387.000000
# mean                 6011.778752   2018.572799      6.510148
# std                  1464.215726      2.210822      3.494403
# min                     0.000000   2012.000000      1.000000
# 25%                  5325.000000   2018.000000      3.000000
# 50%                  5850.000000   2019.000000      7.000000
# ...

# %%
filename
# Out:
# '263_Bengal_Gram_Dal_(Chana_Dal).xlsx'

# %%
CropData.describe().to_excel(resultsPath / f"{filename.split('.')[0]}_Summary.xlsx")
