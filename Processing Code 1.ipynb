# %%
! pip3 install openpyxl

# %%
import os
import openpyxl as xl
import pandas as pd

# %%
CollatedDirectory =  "/home/dmacs/Documents/Pranav_Phanindra/Data_Scraping_Final/Data_Part_2/Collated"

# %%
DataFiles = os.listdir(CollatedDirectory)
DataFiles.sort()
DataFiles
# Out:
# ['12_Mustard.xlsx',
#  '13_Soyabean.xlsx',
#  '1_Wheat.xlsx',
#  '263_Bengal+Gram+Dal+(Chana+Dal).xlsx',
#  '29_Barley+(Jau).xlsx',
#  '4_Maize.xlsx',
#  '6_Bengal+Gram(Gram)(Whole).xlsx']

# %%
for file in DataFiles :
    wb = xl.load_workbook(CollatedDirectory+'/{}'.format(file))
    print(wb.sheetnames,'\n')
    wb.close()

# %%
 wb = xl.load_workbook(CollatedDirectory+'/12_Mustard.xlsx')

# %%
sheets = wb.sheetnames

# %%
sheets
# Out:
# ['Andaman and Nicobar',
#  'Andhra Pradesh',
#  'Arunachal Pradesh',
#  'Assam',
#  'Bihar',
#  'Chattisgarh',
#  'Chandigarh',
#  'Daman and Diu',
#  'NCT of Delhi',
#  'Dadra and Nagar Haveli',
#  'Gujarat',
#  'Goa',
#  'Himachal Pradesh',
#  'Haryana',
#  'Jammu and Kashmir',
#  'Jharkhand',
#  'Karnataka',
#  'Kerala',
#  'Lakshadweep',
#  'Meghalaya',
#  'Maharashtra',
#  'Manipur',
#  'Madhya Pradesh',
#  'Mizoram',
#  'Nagaland',
#  'Odisha',
#  'Punjab',
#  'Pondicherry',
#  'Rajasthan',
#  'Sikkim',
#  'Telangana',
#  'Tamil Nadu',
#  'Tripura',
#  'Uttrakhand',
#  'Uttar Pradesh',
#  'West Bengal']

# %%
for sheet in sheets :
    print(wb[sheet].max_row,wb[sheet].max_column)
# Out:
# 2 14
# 22 12
# 12 12
# 5735 12
# 463 12
# 1 2
# 2 14
# 2 14
# 5273 12
# 2 14
# 79156 12
# 2 14
# 32 12
# 23666 12
# 2 14
# 3707 12
# 3485 12
# 553 12
# 2 14
# 51 12
# 7847 12
# 691 12
# 207728 12
# 415 12
# 2 14
# 177 12
# 1116 12
# 107 12
# 255783 12
# 2 14
# 476 12
# 29 12
# 3 12
# 594 12
# 352555 12
# 64998 12

# %%
df = pd.DataFrame(wb[ 'Andhra Pradesh'].values)

# %%
df.iloc[:,1:]
# Out:
#         1               2                                      3          4   \
# 0   Sl no.   District Name                            Market Name  Commodity
# 1        1        Kurnool                                  Adoni    Mustard
# 2        2        Kurnool                                   Alur    Mustard
# 3        3        Kurnool                                   Alur    Mustard
# 4        4        Kurnool                                   Alur    Mustard
# 5        5        Kurnool                                   Alur    Mustard
# 6        6        Kurnool                                   Alur    Mustard
# 7        7        Kurnool                                   Alur    Mustard
# 8        8       Cuddapah                               Cuddapah    Mustard
# 9        9       Cuddapah                               Cuddapah    Mustard
# 10      10       Cuddapah                               Cuddapah    Mustard
# ...

# %%
wb.close()

# %%
df.columns = df.iloc[0,:]

# %%
df = df.iloc[1:,1:]

# %%
df
# Out:
# 0  Sl no.   District Name                            Market Name Commodity  \
# 1       1        Kurnool                                  Adoni   Mustard
# 2       2        Kurnool                                   Alur   Mustard
# 3       3        Kurnool                                   Alur   Mustard
# 4       4        Kurnool                                   Alur   Mustard
# 5       5        Kurnool                                   Alur   Mustard
# 6       6        Kurnool                                   Alur   Mustard
# 7       7        Kurnool                                   Alur   Mustard
# 8       8       Cuddapah                               Cuddapah   Mustard
# 9       9       Cuddapah                               Cuddapah   Mustard
# 10     10       Cuddapah                               Cuddapah   Mustard
# 11     11       Cuddapah                               Cuddapah   Mustard
# 12     12       Cuddapah                               Cuddapah   Mustard
# ...

# %%
df = df.set_index('Sl no.')
# Out:
# /home/dmacs/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6982: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)

# %%
df.columns
# Out:
# Index(['District Name', 'Market Name', 'Commodity', 'Variety', 'Grade',
#        'Min Price (Rs./Quintal)', 'Max Price (Rs./Quintal)',
#        'Modal Price (Rs./Quintal)', 'Price Date', 'State'],
#       dtype='object', name=0)

# %%
df
# Out:
# 0        District Name                            Market Name Commodity  \
# Sl no.
# 1             Kurnool                                  Adoni   Mustard
# 2             Kurnool                                   Alur   Mustard
# 3             Kurnool                                   Alur   Mustard
# 4             Kurnool                                   Alur   Mustard
# 5             Kurnool                                   Alur   Mustard
# 6             Kurnool                                   Alur   Mustard
# 7             Kurnool                                   Alur   Mustard
# 8            Cuddapah                               Cuddapah   Mustard
# 9            Cuddapah                               Cuddapah   Mustard
# 10           Cuddapah                               Cuddapah   Mustard
# 11           Cuddapah                               Cuddapah   Mustard
# 12           Cuddapah                               Cuddapah   Mustard
# ...

# %%
df['Avg_Price'] = (df['Min Price (Rs./Quintal)']+df['Max Price (Rs./Quintal)'])/2

# %%
df
# Out:
# 0        District Name                            Market Name Commodity  \
# Sl no.
# 1             Kurnool                                  Adoni   Mustard
# 2             Kurnool                                   Alur   Mustard
# 3             Kurnool                                   Alur   Mustard
# 4             Kurnool                                   Alur   Mustard
# 5             Kurnool                                   Alur   Mustard
# 6             Kurnool                                   Alur   Mustard
# 7             Kurnool                                   Alur   Mustard
# 8            Cuddapah                               Cuddapah   Mustard
# 9            Cuddapah                               Cuddapah   Mustard
# 10           Cuddapah                               Cuddapah   Mustard
# 11           Cuddapah                               Cuddapah   Mustard
# 12           Cuddapah                               Cuddapah   Mustard
# ...

# %%
df['Avg_Price'].mean()
# Out:
# 2767.8571428571427

# %%
df['Min Price (Rs./Quintal)'].mean()
# Out:
# 2722.809523809524

# %%
df['Max Price (Rs./Quintal)'].mean()
# Out:
# 2812.904761904762
