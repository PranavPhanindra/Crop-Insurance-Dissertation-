# %%
# !pip3 install openpyxl 
from pathlib import Path

import os
import openpyxl as xl
import pandas as pd

Collated =  Path("/home/dmacs/Documents/Pranav_Phanindra/Data_Scraping_Final/Data_Part_2/Collated")

# %%
DataFiles = os.listdir(Collated)
DataFiles.sort()
print(DataFiles)
# Out:
# ['12_Mustard.csv', '12_Mustard.xlsx', '13_Soyabean.csv', '13_Soyabean.xlsx', '1_Wheat.xlsx', '263_Bengal+Gram+Dal+(Chana+Dal).xlsx', '29_Barley+(Jau).xlsx', '4_Maize.xlsx', 'Commodity_Graphs', 'State_Graphs']

# %%
Mustard = pd.read_csv(Collated / DataFiles[0])

# %%
Mustard
# Out:
#          Unnamed: 0 District Name  Market Name Commodity   Variety    Grade  \
# 0                 0      Kurnool        Adoni   Mustard     Other      FAQ
# 1                 1      Kurnool         Alur   Mustard     Other   Medium
# 2                 2      Kurnool         Alur   Mustard   Mustard   Medium
# 3                 3      Kurnool         Alur   Mustard     Other   Medium
# 4                 4      Kurnool         Alur   Mustard   Mustard   Medium
# ...             ...           ...          ...       ...       ...      ...
# 1014643       64992   Coochbehar   Toofanganj   Mustard   Mustard      FAQ
# 1014644       64993   Coochbehar   Toofanganj   Mustard   Mustard      FAQ
# 1014645       64994   Coochbehar   Toofanganj   Mustard   Mustard      FAQ
# 1014646       64995   Coochbehar   Toofanganj   Mustard   Mustard      FAQ
# 1014647       64996   Coochbehar   Toofanganj   Mustard   Mustard      FAQ
#
#          Min Price (Rs./Quintal)  Max Price (Rs./Quintal)  \
# ...

# %%
Mustard[Mustard['State'] == 'Andhra Pradesh']
# Out:
#     Unnamed: 0   District Name                            Market Name  \
# 0            0        Kurnool                                  Adoni
# 1            1        Kurnool                                   Alur
# 2            2        Kurnool                                   Alur
# 3            3        Kurnool                                   Alur
# 4            4        Kurnool                                   Alur
# 5            5        Kurnool                                   Alur
# 6            6        Kurnool                                   Alur
# 7            7       Cuddapah                               Cuddapah
# 8            8       Cuddapah                               Cuddapah
# 9            9       Cuddapah                               Cuddapah
# 10          10       Cuddapah                               Cuddapah
# 11          11       Cuddapah                               Cuddapah
# 12          12       Cuddapah                               Cuddapah
# ...
